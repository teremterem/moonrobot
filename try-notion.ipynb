# %%
import os
from pprint import pprint

import requests
from dotenv import load_dotenv

load_dotenv()

MRB_NOTION_TOKEN = os.environ['MRB_NOTION_TOKEN']
MRB_NOTION_ENTRYPOINTS_DB_ID = os.environ['MRB_NOTION_ENTRYPOINTS_DB_ID']

# %%
with requests.post(
        'https://api.notion.com/v1/search',
        headers={
            'Authorization': f"Bearer {MRB_NOTION_TOKEN}",
            'Notion-Version': '2021-08-16',
        },
        json={},
) as resp:
    pprint(resp.json())
# Out:
# {'has_more': False,
#  'next_cursor': None,
#  'object': 'list',
#  'results': [{'archived': False,
#               'cover': None,
#               'created_time': '2021-10-09T12:51:00.000Z',
#               'icon': None,
#               'id': '0e18b425-0e6d-4d17-9111-dbec26065e6c',
#               'last_edited_time': '2021-10-11T17:32:00.000Z',
#               'object': 'page',
#               'parent': {'page_id': '2094ac20-ffdb-40b0-8491-f4b43b4bc6fb',
#                          'type': 'page_id'},
#               'properties': {'title': {'id': 'title',
#                                        'title': [{'annotations': {'bold': False,
#                                                                   'code': False,
#                                                                   'color': 'default',
#                                                                   'italic': False,
#                                                                   'strikethrough': False,
#                                                                   'underline': False},
#                                                   'href': None,
#                                                   'plain_text': 'Bot',
#                                                   'text': {'content': 'Bot',
#                                                            'link': None},
#                                                   'type': 'text'}],
#                                        'type': 'title'}},
#               'url': 'https://www.notion.so/Bot-0e18b4250e6d4d179111dbec26065e6c'},
#              {'cover': None,
#               'created_time': '2021-10-11T17:32:00.000Z',
#               'icon': None,
#               'id': 'c1a27495-e729-4c94-8291-b4681269e5ed',
#               'last_edited_time': '2021-10-11T17:32:00.000Z',
#               'object': 'database',
#               'parent': {'page_id': '0e18b425-0e6d-4d17-9111-dbec26065e6c',
#                          'type': 'page_id'},
#               'properties': {'Name': {'id': 'title',
#                                       'name': 'Name',
#                                       'title': {},
#                                       'type': 'title'},
#                              'Tags': {'id': 'ki%3A%3C',
#                                       'multi_select': {'options': []},
#                                       'name': 'Tags',
#                                       'type': 'multi_select'}},
#               'title': [{'annotations': {'bold': False,
#                                          'code': False,
#                                          'color': 'default',
#                                          'italic': False,
#                                          'strikethrough': False,
#                                          'underline': False},
#                          'href': None,
#                          'plain_text': 'Messages',
#                          'text': {'content': 'Messages', 'link': None},
#                          'type': 'text'}],
#               'url': 'https://www.notion.so/c1a27495e7294c948291b4681269e5ed'},
#              {'archived': False,
#               'cover': None,
#               'created_time': '2021-10-11T17:32:00.000Z',
#               'icon': None,
#               'id': 'a5342882-cf93-4101-9150-38f7b2fac0cc',
#               'last_edited_time': '2021-10-11T17:32:00.000Z',
#               'object': 'page',
#               'parent': {'database_id': 'ce81cf57-fb89-458b-b5df-57e98331e097',
#                          'type': 'database_id'},
#               'properties': {'Name': {'id': 'title',
#                                       'title': [],
#                                       'type': 'title'},
#                              'Tags': {'id': 'aeiK',
#                                       'multi_select': None,
#                                       'type': 'multi_select'}},
#               'url': 'https://www.notion.so/a5342882cf934101915038f7b2fac0cc'},
#              {'archived': False,
#               'cover': None,
#               'created_time': '2021-10-11T17:25:00.000Z',
#               'icon': None,
#               'id': 'c6c86a3f-8b6e-49e0-9255-cf3e9f8a8dbf',
#               'last_edited_time': '2021-10-11T17:25:00.000Z',
#               'object': 'page',
#               'parent': {'database_id': 'ce81cf57-fb89-458b-b5df-57e98331e097',
#                          'type': 'database_id'},
#               'properties': {'Name': {'id': 'title',
#                                       'title': [],
#                                       'type': 'title'},
#                              'Tags': {'id': 'aeiK',
#                                       'multi_select': None,
#                                       'type': 'multi_select'}},
#               'url': 'https://www.notion.so/c6c86a3f8b6e49e09255cf3e9f8a8dbf'},
#              {'archived': False,
#               'cover': None,
#               'created_time': '2021-10-11T17:25:00.000Z',
#               'icon': None,
#               'id': '3e88cf8b-a5c7-4ad1-8d8d-9fb79d52187d',
#               'last_edited_time': '2021-10-11T17:25:00.000Z',
#               'object': 'page',
#               'parent': {'database_id': 'ce81cf57-fb89-458b-b5df-57e98331e097',
#                          'type': 'database_id'},
#               'properties': {'Name': {'id': 'title',
#                                       'title': [],
#                                       'type': 'title'},
#                              'Tags': {'id': 'aeiK',
#                                       'multi_select': None,
#                                       'type': 'multi_select'}},
#               'url': 'https://www.notion.so/3e88cf8ba5c74ad18d8d9fb79d52187d'},
#              {'archived': False,
#               'cover': None,
#               'created_time': '2021-10-11T17:25:00.000Z',
#               'icon': None,
#               'id': 'b098e312-1618-43f1-abc9-c8b0cd19036e',
#               'last_edited_time': '2021-10-11T17:25:00.000Z',
#               'object': 'page',
#               'parent': {'database_id': 'ce81cf57-fb89-458b-b5df-57e98331e097',
#                          'type': 'database_id'},
#               'properties': {'Name': {'id': 'title',
#                                       'title': [],
#                                       'type': 'title'},
#                              'Tags': {'id': 'aeiK',
#                                       'multi_select': None,
#                                       'type': 'multi_select'}},
#               'url': 'https://www.notion.so/b098e312161843f1abc9c8b0cd19036e'},
#              {'archived': False,
#               'cover': None,
#               'created_time': '2021-10-10T18:36:00.000Z',
#               'icon': None,
#               'id': '98b651c3-9153-4bef-97b3-4f72bccb0f20',
#               'last_edited_time': '2021-10-10T18:38:00.000Z',
#               'object': 'page',
#               'parent': {'database_id': '170ff8e0-2d71-4a9f-a4c4-ca3fd450f283',
#                          'type': 'database_id'},
#               'properties': {'Message': {'id': '%3DCG%3D',
#                                          'rich_text': [{'annotations': {'bold': False,
#                                                                         'code': True,
#                                                                         'color': 'default',
#                                                                         'italic': False,
#                                                                         'strikethrough': False,
#                                                                         'underline': False},
#                                                         'href': None,
#                                                         'plain_text': 'blah',
#                                                         'text': {'content': 'blah',
#                                                                  'link': None},
#                                                         'type': 'text'},
#                                                        {'annotations': {'bold': False,
#                                                                         'code': False,
#                                                                         'color': 'default',
#                                                                         'italic': False,
#                                                                         'strikethrough': False,
#                                                                         'underline': False},
#                                                         'href': None,
#                                                         'plain_text': ' BLAH ',
#                                                         'text': {'content': ' '
#                                                                             'BLAH ',
#                                                                  'link': None},
#                                                         'type': 'text'},
#                                                        {'annotations': {'bold': False,
#                                                                         'code': False,
#                                                                         'color': 'default',
#                                                                         'italic': False,
#                                                                         'strikethrough': True,
#                                                                         'underline': False},
#                                                         'href': None,
#                                                         'plain_text': 'blah ',
#                                                         'text': {'content': 'blah ',
#                                                                  'link': None},
#                                                         'type': 'text'},
#                                                        {'annotations': {'bold': False,
#                                                                         'code': False,
#                                                                         'color': 'default',
#                                                                         'italic': False,
#                                                                         'strikethrough': True,
#                                                                         'underline': True},
#                                                         'href': None,
#                                                         'plain_text': 'blah ',
#                                                         'text': {'content': 'blah ',
#                                                                  'link': None},
#                                                         'type': 'text'},
#                                                        {'annotations': {'bold': False,
#                                                                         'code': False,
#                                                                         'color': 'default',
#                                                                         'italic': True,
#                                                                         'strikethrough': True,
#                                                                         'underline': True},
#                                                         'href': None,
#                                                         'plain_text': 'blah ',
#                                                         'text': {'content': 'blah ',
#                                                                  'link': None},
#                                                         'type': 'text'},
#                                                        {'annotations': {'bold': True,
#                                                                         'code': False,
#                                                                         'color': 'default',
#                                                                         'italic': True,
#                                                                         'strikethrough': True,
#                                                                         'underline': True},
#                                                         'href': None,
#                                                         'plain_text': 'blah',
#                                                         'text': {'content': 'blah',
#                                                                  'link': None},
#                                                         'type': 'text'},
#                                                        {'annotations': {'bold': False,
#                                                                         'code': False,
#                                                                         'color': 'default',
#                                                                         'italic': True,
#                                                                         'strikethrough': True,
#                                                                         'underline': True},
#                                                         'href': None,
#                                                         'plain_text': ' blah',
#                                                         'text': {'content': ' '
#                                                                             'blah',
#                                                                  'link': None},
#                                                         'type': 'text'},
#                                                        {'annotations': {'bold': False,
#                                                                         'code': False,
#                                                                         'color': 'default',
#                                                                         'italic': False,
#                                                                         'strikethrough': True,
#                                                                         'underline': True},
#                                                         'href': None,
#                                                         'plain_text': ' blah',
#                                                         'text': {'content': ' '
#                                                                             'blah',
#                                                                  'link': None},
#                                                         'type': 'text'},
#                                                        {'annotations': {'bold': False,
#                                                                         'code': False,
#                                                                         'color': 'default',
#                                                                         'italic': False,
#                                                                         'strikethrough': True,
#                                                                         'underline': False},
#                                                         'href': None,
#                                                         'plain_text': ' blah',
#                                                         'text': {'content': ' '
#                                                                             'blah',
#                                                                  'link': None},
#                                                         'type': 'text'},
#                                                        {'annotations': {'bold': False,
#                                                                         'code': False,
#                                                                         'color': 'default',
#                                                                         'italic': False,
#                                                                         'strikethrough': False,
#                                                                         'underline': False},
#                                                         'href': None,
#                                                         'plain_text': ' BLAH ',
#                                                         'text': {'content': ' '
#                                                                             'BLAH ',
#                                                                  'link': None},
#                                                         'type': 'text'},
#                                                        {'annotations': {'bold': False,
#                                                                         'code': False,
#                                                                         'color': 'default',
#                                                                         'italic': False,
#                                                                         'strikethrough': True,
#                                                                         'underline': False},
#                                                         'href': None,
#                                                         'plain_text': 'b',
#                                                         'text': {'content': 'b',
#                                                                  'link': None},
#                                                         'type': 'text'},
#                                                        {'annotations': {'bold': False,
#                                                                         'code': True,
#                                                                         'color': 'default',
#                                                                         'italic': False,
#                                                                         'strikethrough': True,
#                                                                         'underline': False},
#                                                         'href': None,
#                                                         'plain_text': 'la',
#                                                         'text': {'content': 'la',
#                                                                  'link': None},
#                                                         'type': 'text'},
#                                                        {'annotations': {'bold': False,
#                                                                         'code': False,
#                                                                         'color': 'default',
#                                                                         'italic': False,
#                                                                         'strikethrough': True,
#                                                                         'underline': False},
#                                                         'href': None,
#                                                         'plain_text': 'h',
#                                                         'text': {'content': 'h',
#                                                                  'link': None},
#                                                         'type': 'text'}],
#                                          'type': 'rich_text'},
#                              'Name': {'id': 'title',
#                                       'title': [{'annotations': {'bold': False,
#                                                                  'code': False,
#                                                                  'color': 'default',
#                                                                  'italic': False,
#                                                                  'strikethrough': False,
#                                                                  'underline': False},
#                                                  'href': None,
#                                                  'plain_text': 'ta',
#                                                  'text': {'content': 'ta',
#                                                           'link': None},
#                                                  'type': 'text'}],
#                                       'type': 'title'},
#                              'Tags': {'id': 'RAZd',
#                                       'multi_select': None,
#                                       'type': 'multi_select'}},
#               'url': 'https://www.notion.so/ta-98b651c391534bef97b34f72bccb0f20'},
#              {'cover': None,
#               'created_time': '2021-10-09T13:27:00.000Z',
#               'icon': None,
#               'id': '170ff8e0-2d71-4a9f-a4c4-ca3fd450f283',
#               'last_edited_time': '2021-10-10T18:36:00.000Z',
#               'object': 'database',
#               'parent': {'page_id': '0e18b425-0e6d-4d17-9111-dbec26065e6c',
#                          'type': 'page_id'},
#               'properties': {'Message': {'id': '%3DCG%3D',
#                                          'name': 'Message',
#                                          'rich_text': {},
#                                          'type': 'rich_text'},
#                              'Name': {'id': 'title',
#                                       'name': 'Name',
#                                       'title': {},
#                                       'type': 'title'},
#                              'Tags': {'id': 'RAZd',
#                                       'multi_select': {'options': []},
#                                       'name': 'Tags',
#                                       'type': 'multi_select'}},
#               'title': [{'annotations': {'bold': False,
#                                          'code': False,
#                                          'color': 'default',
#                                          'italic': False,
#                                          'strikethrough': False,
#                                          'underline': False},
#                          'href': None,
#                          'plain_text': 'Entry points',
#                          'text': {'content': 'Entry points', 'link': None},
#                          'type': 'text'}],
#               'url': 'https://www.notion.so/170ff8e02d714a9fa4c4ca3fd450f283'},
#              {'archived': False,
#               'cover': None,
#               'created_time': '2021-10-10T18:22:00.000Z',
#               'icon': None,
#               'id': 'b763fd47-9666-412e-a61b-73845f1cd108',
#               'last_edited_time': '2021-10-10T18:22:00.000Z',
#               'object': 'page',
#               'parent': {'database_id': '170ff8e0-2d71-4a9f-a4c4-ca3fd450f283',
#                          'type': 'database_id'},
#               'properties': {'Message': {'id': '%3DCG%3D',
#                                          'rich_text': [{'annotations': {'bold': False,
#                                                                         'code': False,
#                                                                         'color': 'default',
#                                                                         'italic': False,
#                                                                         'strikethrough': False,
#                                                                         'underline': False},
#                                                         'href': None,
#                                                         'plain_text': 'la la '
#                                                                       'la la',
#                                                         'text': {'content': 'la '
#                                                                             'la '
#                                                                             'la '
#                                                                             'la',
#                                                                  'link': None},
#                                                         'type': 'text'}],
#                                          'type': 'rich_text'},
#                              'Name': {'id': 'title',
#                                       'title': [{'annotations': {'bold': False,
#                                                                  'code': False,
#                                                                  'color': 'default',
#                                                                  'italic': False,
#                                                                  'strikethrough': False,
#                                                                  'underline': False},
#                                                  'href': None,
#                                                  'plain_text': 'la',
#                                                  'text': {'content': 'la',
#                                                           'link': None},
#                                                  'type': 'text'}],
#                                       'type': 'title'},
#                              'Tags': {'id': 'RAZd',
#                                       'multi_select': None,
#                                       'type': 'multi_select'}},
#               'url': 'https://www.notion.so/la-b763fd479666412ea61b73845f1cd108'},
#              {'archived': False,
#               'cover': None,
#               'created_time': '2021-10-09T14:59:00.000Z',
#               'icon': None,
#               'id': '5cea696e-cbec-43c0-bcea-e4ff7b98b25a',
#               'last_edited_time': '2021-10-09T18:56:00.000Z',
#               'object': 'page',
#               'parent': {'database_id': '170ff8e0-2d71-4a9f-a4c4-ca3fd450f283',
#                          'type': 'database_id'},
#               'properties': {'Message': {'id': '%3DCG%3D',
#                                          'rich_text': [{'annotations': {'bold': False,
#                                                                         'code': False,
#                                                                         'color': 'green_background',
#                                                                         'italic': False,
#                                                                         'strikethrough': False,
#                                                                         'underline': False},
#                                                         'href': None,
#                                                         'plain_text': 'ya',
#                                                         'text': {'content': 'ya',
#                                                                  'link': None},
#                                                         'type': 'text'},
#                                                        {'annotations': {'bold': False,
#                                                                         'code': True,
#                                                                         'color': 'green_background',
#                                                                         'italic': False,
#                                                                         'strikethrough': False,
#                                                                         'underline': False},
#                                                         'href': None,
#                                                         'plain_text': 'y',
#                                                         'text': {'content': 'y',
#                                                                  'link': None},
#                                                         'type': 'text'},
#                                                        {'annotations': {'bold': False,
#                                                                         'code': True,
#                                                                         'color': 'red_background',
#                                                                         'italic': False,
#                                                                         'strikethrough': False,
#                                                                         'underline': False},
#                                                         'href': None,
#                                                         'plain_text': 'a',
#                                                         'text': {'content': 'a',
#                                                                  'link': None},
#                                                         'type': 'text'},
#                                                        {'annotations': {'bold': False,
#                                                                         'code': False,
#                                                                         'color': 'green_background',
#                                                                         'italic': False,
#                                                                         'strikethrough': False,
#                                                                         'underline': False},
#                                                         'href': None,
#                                                         'plain_text': ' ',
#                                                         'text': {'content': ' ',
#                                                                  'link': None},
#                                                         'type': 'text'},
#                                                        {'annotations': {'bold': True,
#                                                                         'code': False,
#                                                                         'color': 'green_background',
#                                                                         'italic': False,
#                                                                         'strikethrough': False,
#                                                                         'underline': False},
#                                                         'href': None,
#                                                         'plain_text': 'ds',
#                                                         'text': {'content': 'ds',
#                                                                  'link': None},
#                                                         'type': 'text'},
#                                                        {'annotations': {'bold': False,
#                                                                         'code': False,
#                                                                         'color': 'default',
#                                                                         'italic': False,
#                                                                         'strikethrough': False,
#                                                                         'underline': False},
#                                                         'href': None,
#                                                         'plain_text': ' trata\n'
#                                                                       '\n'
#                                                                       '@teremterem\n'
#                                                                       '\n',
#                                                         'text': {'content': ' '
#                                                                             'trata\n'
#                                                                             '\n'
#                                                                             '@teremterem\n'
#                                                                             '\n',
#                                                                  'link': None},
#                                                         'type': 'text'},
#                                                        {'annotations': {'bold': False,
#                                                                         'code': True,
#                                                                         'color': 'default',
#                                                                         'italic': False,
#                                                                         'strikethrough': False,
#                                                                         'underline': False},
#                                                         'href': None,
#                                                         'plain_text': 'code',
#                                                         'text': {'content': 'code',
#                                                                  'link': None},
#                                                         'type': 'text'}],
#                                          'type': 'rich_text'},
#                              'Name': {'id': 'title',
#                                       'title': [{'annotations': {'bold': False,
#                                                                  'code': False,
#                                                                  'color': 'green_background',
#                                                                  'italic': False,
#                                                                  'strikethrough': False,
#                                                                  'underline': False},
#                                                  'href': None,
#                                                  'plain_text': 'yaya',
#                                                  'text': {'content': 'yaya',
#                                                           'link': None},
#                                                  'type': 'text'}],
#                                       'type': 'title'},
#                              'Tags': {'id': 'RAZd',
#                                       'multi_select': None,
#                                       'type': 'multi_select'}},
#               'url': 'https://www.notion.so/yaya-5cea696ecbec43c0bceae4ff7b98b25a'},
#              {'archived': False,
#               'cover': None,
#               'created_time': '2021-10-09T18:55:00.000Z',
#               'icon': None,
#               'id': '15172e25-d351-4501-a424-0c1e0d42430e',
#               'last_edited_time': '2021-10-09T18:55:00.000Z',
#               'object': 'page',
#               'parent': {'database_id': '170ff8e0-2d71-4a9f-a4c4-ca3fd450f283',
#                          'type': 'database_id'},
#               'properties': {'Message': {'id': '%3DCG%3D',
#                                          'rich_text': [],
#                                          'type': 'rich_text'},
#                              'Name': {'id': 'title',
#                                       'title': [{'annotations': {'bold': False,
#                                                                  'code': False,
#                                                                  'color': 'default',
#                                                                  'italic': False,
#                                                                  'strikethrough': False,
#                                                                  'underline': False},
#                                                  'href': None,
#                                                  'plain_text': 'tototo',
#                                                  'text': {'content': 'tototo',
#                                                           'link': None},
#                                                  'type': 'text'}],
#                                       'type': 'title'},
#                              'Tags': {'id': 'RAZd',
#                                       'multi_select': None,
#                                       'type': 'multi_select'}},
#               'url': 'https://www.notion.so/tototo-15172e25d3514501a4240c1e0d42430e'},
#              {'archived': False,
#               'cover': None,
#               'created_time': '2021-10-09T14:07:00.000Z',
#               'icon': None,
#               'id': '519e4b50-0a67-46f8-ab21-3f95db1d5cdd',
#               'last_edited_time': '2021-10-09T18:52:00.000Z',
#               'object': 'page',
#               'parent': {'database_id': '170ff8e0-2d71-4a9f-a4c4-ca3fd450f283',
#                          'type': 'database_id'},
#               'properties': {'Message': {'id': '%3DCG%3D',
#                                          'rich_text': [{'annotations': {'bold': False,
#                                                                         'code': False,
#                                                                         'color': 'default',
#                                                                         'italic': False,
#                                                                         'strikethrough': False,
#                                                                         'underline': False},
#                                                         'href': None,
#                                                         'plain_text': 'Hello, '
#                                                                       "I'm "
#                                                                       "Oleksandr's ",
#                                                         'text': {'content': 'Hello, '
#                                                                             "I'm "
#                                                                             "Oleksandr's ",
#                                                                  'link': None},
#                                                         'type': 'text'},
#                                                        {'annotations': {'bold': True,
#                                                                         'code': False,
#                                                                         'color': 'default',
#                                                                         'italic': False,
#                                                                         'strikethrough': False,
#                                                                         'underline': False},
#                                                         'href': None,
#                                                         'plain_text': 'SpokesPersonBot',
#                                                         'text': {'content': 'SpokesPersonBot',
#                                                                  'link': None},
#                                                         'type': 'text'},
#                                                        {'annotations': {'bold': False,
#                                                                         'code': False,
#                                                                         'color': 'default',
#                                                                         'italic': False,
#                                                                         'strikethrough': False,
#                                                                         'underline': False},
#                                                         'href': None,
#                                                         'plain_text': ' ;)',
#                                                         'text': {'content': ' '
#                                                                             ';)',
#                                                                  'link': None},
#                                                         'type': 'text'}],
#                                          'type': 'rich_text'},
#                              'Name': {'id': 'title',
#                                       'title': [{'annotations': {'bold': False,
#                                                                  'code': False,
#                                                                  'color': 'default',
#                                                                  'italic': False,
#                                                                  'strikethrough': False,
#                                                                  'underline': False},
#                                                  'href': None,
#                                                  'plain_text': '/start',
#                                                  'text': {'content': '/start',
#                                                           'link': None},
#                                                  'type': 'text'}],
#                                       'type': 'title'},
#                              'Tags': {'id': 'RAZd',
#                                       'multi_select': None,
#                                       'type': 'multi_select'}},
#               'url': 'https://www.notion.so/start-519e4b500a6746f8ab213f95db1d5cdd'},
#              {'archived': False,
#               'cover': None,
#               'created_time': '2021-10-09T15:04:00.000Z',
#               'icon': None,
#               'id': '678a3147-5f9b-4af2-ac0b-01ba447a10bd',
#               'last_edited_time': '2021-10-09T18:36:00.000Z',
#               'object': 'page',
#               'parent': {'database_id': '170ff8e0-2d71-4a9f-a4c4-ca3fd450f283',
#                          'type': 'database_id'},
#               'properties': {'Message': {'id': '%3DCG%3D',
#                                          'rich_text': [{'annotations': {'bold': True,
#                                                                         'code': False,
#                                                                         'color': 'default',
#                                                                         'italic': False,
#                                                                         'strikethrough': False,
#                                                                         'underline': False},
#                                                         'href': None,
#                                                         'plain_text': 'BOLD '
#                                                                       'bold',
#                                                         'text': {'content': 'BOLD '
#                                                                             'bold',
#                                                                  'link': None},
#                                                         'type': 'text'},
#                                                        {'annotations': {'bold': False,
#                                                                         'code': False,
#                                                                         'color': 'default',
#                                                                         'italic': False,
#                                                                         'strikethrough': False,
#                                                                         'underline': False},
#                                                         'href': None,
#                                                         'plain_text': '\n',
#                                                         'text': {'content': '\n',
#                                                                  'link': None},
#                                                         'type': 'text'},
#                                                        {'annotations': {'bold': False,
#                                                                         'code': False,
#                                                                         'color': 'default',
#                                                                         'italic': True,
#                                                                         'strikethrough': False,
#                                                                         'underline': False},
#                                                         'href': None,
#                                                         'plain_text': 'italic, '
#                                                                       '<em>italic</em>',
#                                                         'text': {'content': 'italic, '
#                                                                             '<em>italic</em>',
#                                                                  'link': None},
#                                                         'type': 'text'},
#                                                        {'annotations': {'bold': False,
#                                                                         'code': False,
#                                                                         'color': 'default',
#                                                                         'italic': False,
#                                                                         'strikethrough': False,
#                                                                         'underline': False},
#                                                         'href': None,
#                                                         'plain_text': '\n',
#                                                         'text': {'content': '\n',
#                                                                  'link': None},
#                                                         'type': 'text'},
#                                                        {'annotations': {'bold': False,
#                                                                         'code': False,
#                                                                         'color': 'default',
#                                                                         'italic': False,
#                                                                         'strikethrough': False,
#                                                                         'underline': True},
#                                                         'href': None,
#                                                         'plain_text': 'underline, '
#                                                                       '<ins>underline</ins>',
#                                                         'text': {'content': 'underline, '
#                                                                             '<ins>underline</ins>',
#                                                                  'link': None},
#                                                         'type': 'text'},
#                                                        {'annotations': {'bold': False,
#                                                                         'code': False,
#                                                                         'color': 'default',
#                                                                         'italic': False,
#                                                                         'strikethrough': False,
#                                                                         'underline': False},
#                                                         'href': None,
#                                                         'plain_text': '\n',
#                                                         'text': {'content': '\n',
#                                                                  'link': None},
#                                                         'type': 'text'},
#                                                        {'annotations': {'bold': False,
#                                                                         'code': False,
# ...
#                                                                             'code '
#                                                                             'block '
#                                                                             'written '
#                                                                             'in '
#                                                                             'the '
#                                                                             'Python '
#                                                                             'programming '
#                                                                             'language</code></pre>',
#                                                                  'link': None},
#                                                         'type': 'text'}],
#                                          'type': 'rich_text'},
#                              'Name': {'id': 'title',
#                                       'title': [{'annotations': {'bold': False,
#                                                                  'code': False,
#                                                                  'color': 'default',
#                                                                  'italic': False,
#                                                                  'strikethrough': False,
#                                                                  'underline': False},
#                                                  'href': None,
#                                                  'plain_text': '/starpt',
#                                                  'text': {'content': '/starpt',
#                                                           'link': None},
#                                                  'type': 'text'}],
#                                       'type': 'title'},
#                              'Tags': {'id': 'RAZd',
#                                       'multi_select': None,
#                                       'type': 'multi_select'}},
#               'url': 'https://www.notion.so/starpt-678a31475f9b4af2ac0b01ba447a10bd'},
#              {'archived': False,
#               'cover': None,
#               'created_time': '2021-10-09T15:04:00.000Z',
#               'icon': None,
#               'id': 'ac063f90-6945-4148-a274-4e40b1889528',
#               'last_edited_time': '2021-10-09T17:24:00.000Z',
#               'object': 'page',
#               'parent': {'database_id': '170ff8e0-2d71-4a9f-a4c4-ca3fd450f283',
#                          'type': 'database_id'},
#               'properties': {'Message': {'id': '%3DCG%3D',
#                                          'rich_text': [{'annotations': {'bold': False,
#                                                                         'code': False,
#                                                                         'color': 'default',
#                                                                         'italic': False,
#                                                                         'strikethrough': False,
#                                                                         'underline': False},
#                                                         'href': None,
#                                                         'plain_text': 'rerere '
#                                                                       'rererer ',
#                                                         'text': {'content': 'rerere '
#                                                                             'rererer ',
#                                                                  'link': None},
#                                                         'type': 'text'},
#                                                        {'annotations': {'bold': True,
#                                                                         'code': False,
#                                                                         'color': 'default',
#                                                                         'italic': True,
#                                                                         'strikethrough': False,
#                                                                         'underline': False},
#                                                         'href': None,
#                                                         'plain_text': 'boit',
#                                                         'text': {'content': 'boit',
#                                                                  'link': None},
#                                                         'type': 'text'},
#                                                        {'annotations': {'bold': False,
#                                                                         'code': False,
#                                                                         'color': 'default',
#                                                                         'italic': False,
#                                                                         'strikethrough': False,
#                                                                         'underline': False},
#                                                         'href': None,
#                                                         'plain_text': '\n\n',
#                                                         'text': {'content': '\n'
#                                                                             '\n',
#                                                                  'link': None},
#                                                         'type': 'text'},
#                                                        {'annotations': {'bold': True,
#                                                                         'code': False,
#                                                                         'color': 'default',
#                                                                         'italic': False,
#                                                                         'strikethrough': False,
#                                                                         'underline': False},
#                                                         'href': None,
#                                                         'plain_text': 'bobobo',
#                                                         'text': {'content': 'bobobo',
#                                                                  'link': None},
#                                                         'type': 'text'},
#                                                        {'annotations': {'bold': False,
#                                                                         'code': False,
#                                                                         'color': 'default',
#                                                                         'italic': False,
#                                                                         'strikethrough': False,
#                                                                         'underline': False},
#                                                         'href': None,
#                                                         'plain_text': ' ',
#                                                         'text': {'content': ' ',
#                                                                  'link': None},
#                                                         'type': 'text'},
#                                                        {'annotations': {'bold': False,
#                                                                         'code': False,
#                                                                         'color': 'default',
#                                                                         'italic': True,
#                                                                         'strikethrough': False,
#                                                                         'underline': False},
#                                                         'href': None,
#                                                         'plain_text': 'ititit',
#                                                         'text': {'content': 'ititit',
#                                                                  'link': None},
#                                                         'type': 'text'},
#                                                        {'annotations': {'bold': False,
#                                                                         'code': False,
#                                                                         'color': 'default',
#                                                                         'italic': False,
#                                                                         'strikethrough': False,
#                                                                         'underline': False},
#                                                         'href': None,
#                                                         'plain_text': '\n',
#                                                         'text': {'content': '\n',
#                                                                  'link': None},
#                                                         'type': 'text'},
#                                                        {'annotations': {'bold': False,
#                                                                         'code': False,
#                                                                         'color': 'default',
#                                                                         'italic': False,
#                                                                         'strikethrough': False,
#                                                                         'underline': True},
#                                                         'href': None,
#                                                         'plain_text': 'unders',
#                                                         'text': {'content': 'unders',
#                                                                  'link': None},
#                                                         'type': 'text'},
#                                                        {'annotations': {'bold': False,
#                                                                         'code': False,
#                                                                         'color': 'default',
#                                                                         'italic': False,
#                                                                         'strikethrough': False,
#                                                                         'underline': False},
#                                                         'href': None,
#                                                         'plain_text': '\n',
#                                                         'text': {'content': '\n',
#                                                                  'link': None},
#                                                         'type': 'text'},
#                                                        {'annotations': {'bold': False,
#                                                                         'code': False,
#                                                                         'color': 'default',
#                                                                         'italic': False,
#                                                                         'strikethrough': False,
#                                                                         'underline': False},
#                                                         'href': 'https://www.google.com/',
#                                                         'plain_text': 'a url',
#                                                         'text': {'content': 'a '
#                                                                             'url',
#                                                                  'link': {'url': 'https://www.google.com/'}},
#                                                         'type': 'text'},
#                                                        {'annotations': {'bold': False,
#                                                                         'code': False,
#                                                                         'color': 'default',
#                                                                         'italic': False,
#                                                                         'strikethrough': False,
#                                                                         'underline': False},
#                                                         'href': None,
#                                                         'plain_text': ' '
#                                                                       'tratata\n'
#                                                                       '\n'
#                                                                       'All <, '
#                                                                       '> and & '
#                                                                       'symbols '
#                                                                       '" \'',
#                                                         'text': {'content': ' '
#                                                                             'tratata\n'
#                                                                             '\n'
#                                                                             'All '
#                                                                             '<, '
#                                                                             '> '
#                                                                             'and '
#                                                                             '& '
#                                                                             'symbols '
#                                                                             '" '
#                                                                             "'",
#                                                                  'link': None},
#                                                         'type': 'text'}],
#                                          'type': 'rich_text'},
#                              'Name': {'id': 'title',
#                                       'title': [{'annotations': {'bold': False,
#                                                                  'code': False,
#                                                                  'color': 'default',
#                                                                  'italic': False,
#                                                                  'strikethrough': False,
#                                                                  'underline': False},
#                                                  'href': None,
#                                                  'plain_text': 'test styles',
#                                                  'text': {'content': 'test '
#                                                                      'styles',
#                                                           'link': None},
#                                                  'type': 'text'}],
#                                       'type': 'title'},
#                              'Tags': {'id': 'RAZd',
#                                       'multi_select': None,
#                                       'type': 'multi_select'}},
#               'url': 'https://www.notion.so/test-styles-ac063f9069454148a2744e40b1889528'}]}

# %%
with requests.post(
        f"https://api.notion.com/v1/databases/{MRB_NOTION_ENTRYPOINTS_DB_ID}/query",
        headers={
            'Authorization': f"Bearer {MRB_NOTION_TOKEN}",
            'Notion-Version': '2021-08-16',
        },
        json={},
) as resp:
    entrypoints_db_content = resp.json()
    pprint(entrypoints_db_content)
# Out:
# {'has_more': False,
#  'next_cursor': None,
#  'object': 'list',
#  'results': [{'archived': False,
#               'cover': None,
#               'created_time': '2021-10-10T18:36:00.000Z',
#               'icon': None,
#               'id': '98b651c3-9153-4bef-97b3-4f72bccb0f20',
#               'last_edited_time': '2021-10-10T18:38:00.000Z',
#               'object': 'page',
#               'parent': {'database_id': '170ff8e0-2d71-4a9f-a4c4-ca3fd450f283',
#                          'type': 'database_id'},
#               'properties': {'Message': {'id': '%3DCG%3D',
#                                          'rich_text': [{'annotations': {'bold': False,
#                                                                         'code': True,
#                                                                         'color': 'default',
#                                                                         'italic': False,
#                                                                         'strikethrough': False,
#                                                                         'underline': False},
#                                                         'href': None,
#                                                         'plain_text': 'blah',
#                                                         'text': {'content': 'blah',
#                                                                  'link': None},
#                                                         'type': 'text'},
#                                                        {'annotations': {'bold': False,
#                                                                         'code': False,
#                                                                         'color': 'default',
#                                                                         'italic': False,
#                                                                         'strikethrough': False,
#                                                                         'underline': False},
#                                                         'href': None,
#                                                         'plain_text': ' BLAH ',
#                                                         'text': {'content': ' '
#                                                                             'BLAH ',
#                                                                  'link': None},
#                                                         'type': 'text'},
#                                                        {'annotations': {'bold': False,
#                                                                         'code': False,
#                                                                         'color': 'default',
#                                                                         'italic': False,
#                                                                         'strikethrough': True,
#                                                                         'underline': False},
#                                                         'href': None,
#                                                         'plain_text': 'blah ',
#                                                         'text': {'content': 'blah ',
#                                                                  'link': None},
#                                                         'type': 'text'},
#                                                        {'annotations': {'bold': False,
#                                                                         'code': False,
#                                                                         'color': 'default',
#                                                                         'italic': False,
#                                                                         'strikethrough': True,
#                                                                         'underline': True},
#                                                         'href': None,
#                                                         'plain_text': 'blah ',
#                                                         'text': {'content': 'blah ',
#                                                                  'link': None},
#                                                         'type': 'text'},
#                                                        {'annotations': {'bold': False,
#                                                                         'code': False,
#                                                                         'color': 'default',
#                                                                         'italic': True,
#                                                                         'strikethrough': True,
#                                                                         'underline': True},
#                                                         'href': None,
#                                                         'plain_text': 'blah ',
#                                                         'text': {'content': 'blah ',
#                                                                  'link': None},
#                                                         'type': 'text'},
#                                                        {'annotations': {'bold': True,
#                                                                         'code': False,
#                                                                         'color': 'default',
#                                                                         'italic': True,
#                                                                         'strikethrough': True,
#                                                                         'underline': True},
#                                                         'href': None,
#                                                         'plain_text': 'blah',
#                                                         'text': {'content': 'blah',
#                                                                  'link': None},
#                                                         'type': 'text'},
#                                                        {'annotations': {'bold': False,
#                                                                         'code': False,
#                                                                         'color': 'default',
#                                                                         'italic': True,
#                                                                         'strikethrough': True,
#                                                                         'underline': True},
#                                                         'href': None,
#                                                         'plain_text': ' blah',
#                                                         'text': {'content': ' '
#                                                                             'blah',
#                                                                  'link': None},
#                                                         'type': 'text'},
#                                                        {'annotations': {'bold': False,
#                                                                         'code': False,
#                                                                         'color': 'default',
#                                                                         'italic': False,
#                                                                         'strikethrough': True,
#                                                                         'underline': True},
#                                                         'href': None,
#                                                         'plain_text': ' blah',
#                                                         'text': {'content': ' '
#                                                                             'blah',
#                                                                  'link': None},
#                                                         'type': 'text'},
#                                                        {'annotations': {'bold': False,
#                                                                         'code': False,
#                                                                         'color': 'default',
#                                                                         'italic': False,
#                                                                         'strikethrough': True,
#                                                                         'underline': False},
#                                                         'href': None,
#                                                         'plain_text': ' blah',
#                                                         'text': {'content': ' '
#                                                                             'blah',
#                                                                  'link': None},
#                                                         'type': 'text'},
#                                                        {'annotations': {'bold': False,
#                                                                         'code': False,
#                                                                         'color': 'default',
#                                                                         'italic': False,
#                                                                         'strikethrough': False,
#                                                                         'underline': False},
#                                                         'href': None,
#                                                         'plain_text': ' BLAH ',
#                                                         'text': {'content': ' '
#                                                                             'BLAH ',
#                                                                  'link': None},
#                                                         'type': 'text'},
#                                                        {'annotations': {'bold': False,
#                                                                         'code': False,
#                                                                         'color': 'default',
#                                                                         'italic': False,
#                                                                         'strikethrough': True,
#                                                                         'underline': False},
#                                                         'href': None,
#                                                         'plain_text': 'b',
#                                                         'text': {'content': 'b',
#                                                                  'link': None},
#                                                         'type': 'text'},
#                                                        {'annotations': {'bold': False,
#                                                                         'code': True,
#                                                                         'color': 'default',
#                                                                         'italic': False,
#                                                                         'strikethrough': True,
#                                                                         'underline': False},
#                                                         'href': None,
#                                                         'plain_text': 'la',
#                                                         'text': {'content': 'la',
#                                                                  'link': None},
#                                                         'type': 'text'},
#                                                        {'annotations': {'bold': False,
#                                                                         'code': False,
#                                                                         'color': 'default',
#                                                                         'italic': False,
#                                                                         'strikethrough': True,
#                                                                         'underline': False},
#                                                         'href': None,
#                                                         'plain_text': 'h',
#                                                         'text': {'content': 'h',
#                                                                  'link': None},
#                                                         'type': 'text'}],
#                                          'type': 'rich_text'},
#                              'Name': {'id': 'title',
#                                       'title': [{'annotations': {'bold': False,
#                                                                  'code': False,
#                                                                  'color': 'default',
#                                                                  'italic': False,
#                                                                  'strikethrough': False,
#                                                                  'underline': False},
#                                                  'href': None,
#                                                  'plain_text': 'ta',
#                                                  'text': {'content': 'ta',
#                                                           'link': None},
#                                                  'type': 'text'}],
#                                       'type': 'title'},
#                              'Tags': {'id': 'RAZd',
#                                       'multi_select': None,
#                                       'type': 'multi_select'}},
#               'url': 'https://www.notion.so/ta-98b651c391534bef97b34f72bccb0f20'},
#              {'archived': False,
#               'cover': None,
#               'created_time': '2021-10-10T18:22:00.000Z',
#               'icon': None,
#               'id': 'b763fd47-9666-412e-a61b-73845f1cd108',
#               'last_edited_time': '2021-10-10T18:22:00.000Z',
#               'object': 'page',
#               'parent': {'database_id': '170ff8e0-2d71-4a9f-a4c4-ca3fd450f283',
#                          'type': 'database_id'},
#               'properties': {'Message': {'id': '%3DCG%3D',
#                                          'rich_text': [{'annotations': {'bold': False,
#                                                                         'code': False,
#                                                                         'color': 'default',
#                                                                         'italic': False,
#                                                                         'strikethrough': False,
#                                                                         'underline': False},
#                                                         'href': None,
#                                                         'plain_text': 'la la '
#                                                                       'la la',
#                                                         'text': {'content': 'la '
#                                                                             'la '
#                                                                             'la '
#                                                                             'la',
#                                                                  'link': None},
#                                                         'type': 'text'}],
#                                          'type': 'rich_text'},
#                              'Name': {'id': 'title',
#                                       'title': [{'annotations': {'bold': False,
#                                                                  'code': False,
#                                                                  'color': 'default',
#                                                                  'italic': False,
#                                                                  'strikethrough': False,
#                                                                  'underline': False},
#                                                  'href': None,
#                                                  'plain_text': 'la',
#                                                  'text': {'content': 'la',
#                                                           'link': None},
#                                                  'type': 'text'}],
#                                       'type': 'title'},
#                              'Tags': {'id': 'RAZd',
#                                       'multi_select': None,
#                                       'type': 'multi_select'}},
#               'url': 'https://www.notion.so/la-b763fd479666412ea61b73845f1cd108'},
#              {'archived': False,
#               'cover': None,
#               'created_time': '2021-10-09T18:55:00.000Z',
#               'icon': None,
#               'id': '15172e25-d351-4501-a424-0c1e0d42430e',
#               'last_edited_time': '2021-10-09T18:55:00.000Z',
#               'object': 'page',
#               'parent': {'database_id': '170ff8e0-2d71-4a9f-a4c4-ca3fd450f283',
#                          'type': 'database_id'},
#               'properties': {'Message': {'id': '%3DCG%3D',
#                                          'rich_text': [],
#                                          'type': 'rich_text'},
#                              'Name': {'id': 'title',
#                                       'title': [{'annotations': {'bold': False,
#                                                                  'code': False,
#                                                                  'color': 'default',
#                                                                  'italic': False,
#                                                                  'strikethrough': False,
#                                                                  'underline': False},
#                                                  'href': None,
#                                                  'plain_text': 'tototo',
#                                                  'text': {'content': 'tototo',
#                                                           'link': None},
#                                                  'type': 'text'}],
#                                       'type': 'title'},
#                              'Tags': {'id': 'RAZd',
#                                       'multi_select': None,
#                                       'type': 'multi_select'}},
#               'url': 'https://www.notion.so/tototo-15172e25d3514501a4240c1e0d42430e'},
#              {'archived': False,
#               'cover': None,
#               'created_time': '2021-10-09T15:04:00.000Z',
#               'icon': None,
#               'id': '678a3147-5f9b-4af2-ac0b-01ba447a10bd',
#               'last_edited_time': '2021-10-09T18:36:00.000Z',
#               'object': 'page',
#               'parent': {'database_id': '170ff8e0-2d71-4a9f-a4c4-ca3fd450f283',
#                          'type': 'database_id'},
#               'properties': {'Message': {'id': '%3DCG%3D',
#                                          'rich_text': [{'annotations': {'bold': True,
#                                                                         'code': False,
#                                                                         'color': 'default',
#                                                                         'italic': False,
#                                                                         'strikethrough': False,
#                                                                         'underline': False},
#                                                         'href': None,
#                                                         'plain_text': 'BOLD '
#                                                                       'bold',
#                                                         'text': {'content': 'BOLD '
#                                                                             'bold',
#                                                                  'link': None},
#                                                         'type': 'text'},
#                                                        {'annotations': {'bold': False,
#                                                                         'code': False,
#                                                                         'color': 'default',
#                                                                         'italic': False,
#                                                                         'strikethrough': False,
#                                                                         'underline': False},
#                                                         'href': None,
#                                                         'plain_text': '\n',
#                                                         'text': {'content': '\n',
#                                                                  'link': None},
#                                                         'type': 'text'},
#                                                        {'annotations': {'bold': False,
#                                                                         'code': False,
#                                                                         'color': 'default',
#                                                                         'italic': True,
#                                                                         'strikethrough': False,
#                                                                         'underline': False},
#                                                         'href': None,
#                                                         'plain_text': 'italic, '
#                                                                       '<em>italic</em>',
#                                                         'text': {'content': 'italic, '
#                                                                             '<em>italic</em>',
#                                                                  'link': None},
#                                                         'type': 'text'},
#                                                        {'annotations': {'bold': False,
#                                                                         'code': False,
#                                                                         'color': 'default',
#                                                                         'italic': False,
#                                                                         'strikethrough': False,
#                                                                         'underline': False},
#                                                         'href': None,
#                                                         'plain_text': '\n',
#                                                         'text': {'content': '\n',
#                                                                  'link': None},
#                                                         'type': 'text'},
#                                                        {'annotations': {'bold': False,
#                                                                         'code': False,
#                                                                         'color': 'default',
#                                                                         'italic': False,
#                                                                         'strikethrough': False,
#                                                                         'underline': True},
#                                                         'href': None,
#                                                         'plain_text': 'underline, '
#                                                                       '<ins>underline</ins>',
#                                                         'text': {'content': 'underline, '
#                                                                             '<ins>underline</ins>',
#                                                                  'link': None},
#                                                         'type': 'text'},
#                                                        {'annotations': {'bold': False,
#                                                                         'code': False,
#                                                                         'color': 'default',
#                                                                         'italic': False,
#                                                                         'strikethrough': False,
#                                                                         'underline': False},
#                                                         'href': None,
#                                                         'plain_text': '\n',
#                                                         'text': {'content': '\n',
#                                                                  'link': None},
#                                                         'type': 'text'},
#                                                        {'annotations': {'bold': False,
#                                                                         'code': False,
#                                                                         'color': 'default',
#                                                                         'italic': False,
#                                                                         'strikethrough': True,
#                                                                         'underline': False},
#                                                         'href': None,
#                                                         'plain_text': 'strikethrough, '
#                                                                       '<strike>strikethrough</strike>, '
#                                                                       '<del>strikethrough</del>',
#                                                         'text': {'content': 'strikethrough, '
#                                                                             '<strike>strikethrough</strike>, '
#                                                                             '<del>strikethrough</del>',
#                                                                  'link': None},
#                                                         'type': 'text'},
#                                                        {'annotations': {'bold': False,
#                                                                         'code': False,
#                                                                         'color': 'default',
#                                                                         'italic': False,
#                                                                         'strikethrough': False,
#                                                                         'underline': False},
#                                                         'href': None,
#                                                         'plain_text': '\n',
#                                                         'text': {'content': '\n',
#                                                                  'link': None},
#                                                         'type': 'text'},
#                                                        {'annotations': {'bold': True,
#                                                                         'code': False,
#                                                                         'color': 'default',
#                                                                         'italic': False,
#                                                                         'strikethrough': False,
#                                                                         'underline': False},
#                                                         'href': None,
#                                                         'plain_text': 'bold ',
#                                                         'text': {'content': 'bold ',
#                                                                  'link': None},
#                                                         'type': 'text'},
#                                                        {'annotations': {'bold': True,
#                                                                         'code': False,
#                                                                         'color': 'default',
#                                                                         'italic': True,
#                                                                         'strikethrough': False,
#                                                                         'underline': False},
#                                                         'href': None,
#                                                         'plain_text': 'italic '
#                                                                       'bold ',
#                                                         'text': {'content': 'italic '
#                                                                             'bold ',
#                                                                  'link': None},
#                                                         'type': 'text'},
#                                                        {'annotations': {'bold': True,
#                                                                         'code': False,
#                                                                         'color': 'default',
#                                                                         'italic': True,
#                                                                         'strikethrough': True,
#                                                                         'underline': False},
#                                                         'href': None,
#                                                         'plain_text': 'italic '
#                                                                       'bold '
#                                                                       'strikethrough',
#                                                         'text': {'content': 'italic '
#                                                                             'bold '
#                                                                             'strikethrough',
#                                                                  'link': None},
#                                                         'type': 'text'},
#                                                        {'annotations': {'bold': True,
#                                                                         'code': False,
#                                                                         'color': 'default',
#                                                                         'italic': True,
#                                                                         'strikethrough': False,
#                                                                         'underline': False},
#                                                         'href': None,
#                                                         'plain_text': ' ',
#                                                         'text': {'content': ' ',
#                                                                  'link': None},
#                                                         'type': 'text'},
#                                                        {'annotations': {'bold': True,
#                                                                         'code': False,
#                                                                         'color': 'default',
#                                                                         'italic': True,
#                                                                         'strikethrough': False,
#                                                                         'underline': True},
#                                                         'href': None,
#                                                         'plain_text': 'underline '
#                                                                       'italic '
#                                                                       'bold',
#                                                         'text': {'content': 'underline '
#                                                                             'italic '
#                                                                             'bold',
#                                                                  'link': None},
#                                                         'type': 'text'},
#                                                        {'annotations': {'bold': True,
#                                                                         'code': False,
#                                                                         'color': 'default',
#                                                                         'italic': False,
#                                                                         'strikethrough': False,
#                                                                         'underline': False},
#                                                         'href': None,
#                                                         'plain_text': ' bold',
#                                                         'text': {'content': ' '
#                                                                             'bold',
#                                                                  'link': None},
#                                                         'type': 'text'},
#                                                        {'annotations': {'bold': False,
#                                                                         'code': False,
#                                                                         'color': 'default',
#                                                                         'italic': False,
#                                                                         'strikethrough': False,
#                                                                         'underline': False},
#                                                         'href': None,
#                                                         'plain_text': '\n',
#                                                         'text': {'content': '\n',
#                                                                  'link': None},
#                                                         'type': 'text'},
#                                                        {'annotations': {'bold': False,
#                                                                         'code': False,
#                                                                         'color': 'default',
#                                                                         'italic': False,
#                                                                         'strikethrough': False,
#                                                                         'underline': False},
#                                                         'href': 'http://www.example.com/',
#                                                         'plain_text': '<a '
#                                                                       'href="http://www.example.com/">inline '
#                                                                       'URL</a>',
#                                                         'text': {'content': '<a '
#                                                                             'href="http://www.example.com/">inline '
#                                                                             'URL</a>',
#                                                                  'link': {'url': 'http://www.example.com/'}},
#                                                         'type': 'text'},
#                                                        {'annotations': {'bold': False,
#                                                                         'code': False,
#                                                                         'color': 'default',
#                                                                         'italic': False,
#                                                                         'strikethrough': False,
#                                                                         'underline': False},
#                                                         'href': None,
#                                                         'plain_text': '\n'
#                                                                       '[uuuser](tg://user?id=210723289)\n'
#                                                                       '\n'
#                                                                       '[user](https://www.google.com/)\n'
#                                                                       '\n'
#                                                                       '<code>inline '
#                                                                       'fixed-width '
#                                                                       'code</code>\n'
#                                                                       '<pre>pre-formatted '
#                                                                       'fixed-width '
#                                                                       'code '
#                                                                       'block</pre>\n'
#                                                                       '<pre><code '
#                                                                       'class="language-python"',
#                                                         'text': {'content': '\n'
#                                                                             '[uuuser](tg://user?id=210723289)\n'
#                                                                             '\n'
#                                                                             '[user](https://www.google.com/)\n'
#                                                                             '\n'
#                                                                             '<code>inline '
#                                                                             'fixed-width '
#                                                                             'code</code>\n'
#                                                                             '<pre>pre-formatted '
#                                                                             'fixed-width '
#                                                                             'code '
#                                                                             'block</pre>\n'
#                                                                             '<pre><code '
#                                                                             'class="language-python"',
#                                                                  'link': None},
#                                                         'type': 'text'},
#                                                        {'annotations': {'bold': False,
#                                                                         'code': False,
#                                                                         'color': 'default',
#                                                                         'italic': False,
#                                                                         'strikethrough': False,
#                                                                         'underline': False},
#                                                         'href': '/ac063f9069454148a2744e40b1889528',
#                                                         'plain_text': '>pre-formatt',
#                                                         'text': {'content': '>pre-formatt',
#                                                                  'link': {'url': '/ac063f9069454148a2744e40b1889528'}},
#                                                         'type': 'text'},
#                                                        {'annotations': {'bold': False,
#                                                                         'code': False,
#                                                                         'color': 'default',
#                                                                         'italic': False,
#                                                                         'strikethrough': False,
#                                                                         'underline': False},
#                                                         'href': None,
#                                                         'plain_text': 'ed '
#                                                                       'fixed-width '
#                                                                       'code '
#                                                                       'block '
#                                                                       'written '
#                                                                       'in the '
#                                                                       'Python '
#                                                                       'programming '
#                                                                       'language</code></pre>',
#                                                         'text': {'content': 'ed '
#                                                                             'fixed-width '
#                                                                             'code '
#                                                                             'block '
#                                                                             'written '
#                                                                             'in '
#                                                                             'the '
#                                                                             'Python '
#                                                                             'programming '
#                                                                             'language</code></pre>',
#                                                                  'link': None},
#                                                         'type': 'text'}],
#                                          'type': 'rich_text'},
#                              'Name': {'id': 'title',
#                                       'title': [{'annotations': {'bold': False,
#                                                                  'code': False,
#                                                                  'color': 'default',
#                                                                  'italic': False,
#                                                                  'strikethrough': False,
#                                                                  'underline': False},
#                                                  'href': None,
#                                                  'plain_text': '/starpt',
#                                                  'text': {'content': '/starpt',
#                                                           'link': None},
#                                                  'type': 'text'}],
#                                       'type': 'title'},
#                              'Tags': {'id': 'RAZd',
#                                       'multi_select': None,
#                                       'type': 'multi_select'}},
#               'url': 'https://www.notion.so/starpt-678a31475f9b4af2ac0b01ba447a10bd'},
#              {'archived': False,
#               'cover': None,
#               'created_time': '2021-10-09T15:04:00.000Z',
#               'icon': None,
#               'id': 'ac063f90-6945-4148-a274-4e40b1889528',
#               'last_edited_time': '2021-10-09T17:24:00.000Z',
#               'object': 'page',
#               'parent': {'database_id': '170ff8e0-2d71-4a9f-a4c4-ca3fd450f283',
#                          'type': 'database_id'},
#               'properties': {'Message': {'id': '%3DCG%3D',
#                                          'rich_text': [{'annotations': {'bold': False,
#                                                                         'code': False,
#                                                                         'color': 'default',
#                                                                         'italic': False,
#                                                                         'strikethrough': False,
#                                                                         'underline': False},
#                                                         'href': None,
#                                                         'plain_text': 'rerere '
#                                                                       'rererer ',
#                                                         'text': {'content': 'rerere '
#                                                                             'rererer ',
#                                                                  'link': None},
#                                                         'type': 'text'},
#                                                        {'annotations': {'bold': True,
#                                                                         'code': False,
#                                                                         'color': 'default',
#                                                                         'italic': True,
#                                                                         'strikethrough': False,
#                                                                         'underline': False},
#                                                         'href': None,
#                                                         'plain_text': 'boit',
#                                                         'text': {'content': 'boit',
#                                                                  'link': None},
#                                                         'type': 'text'},
#                                                        {'annotations': {'bold': False,
#                                                                         'code': False,
#                                                                         'color': 'default',
#                                                                         'italic': False,
#                                                                         'strikethrough': False,
#                                                                         'underline': False},
#                                                         'href': None,
# ...
#                                                                             '<, '
#                                                                             '> '
#                                                                             'and '
#                                                                             '& '
#                                                                             'symbols '
#                                                                             '" '
#                                                                             "'",
#                                                                  'link': None},
#                                                         'type': 'text'}],
#                                          'type': 'rich_text'},
#                              'Name': {'id': 'title',
#                                       'title': [{'annotations': {'bold': False,
#                                                                  'code': False,
#                                                                  'color': 'default',
#                                                                  'italic': False,
#                                                                  'strikethrough': False,
#                                                                  'underline': False},
#                                                  'href': None,
#                                                  'plain_text': 'test styles',
#                                                  'text': {'content': 'test '
#                                                                      'styles',
#                                                           'link': None},
#                                                  'type': 'text'}],
#                                       'type': 'title'},
#                              'Tags': {'id': 'RAZd',
#                                       'multi_select': None,
#                                       'type': 'multi_select'}},
#               'url': 'https://www.notion.so/test-styles-ac063f9069454148a2744e40b1889528'},
#              {'archived': False,
#               'cover': None,
#               'created_time': '2021-10-09T14:59:00.000Z',
#               'icon': None,
#               'id': '5cea696e-cbec-43c0-bcea-e4ff7b98b25a',
#               'last_edited_time': '2021-10-09T18:56:00.000Z',
#               'object': 'page',
#               'parent': {'database_id': '170ff8e0-2d71-4a9f-a4c4-ca3fd450f283',
#                          'type': 'database_id'},
#               'properties': {'Message': {'id': '%3DCG%3D',
#                                          'rich_text': [{'annotations': {'bold': False,
#                                                                         'code': False,
#                                                                         'color': 'green_background',
#                                                                         'italic': False,
#                                                                         'strikethrough': False,
#                                                                         'underline': False},
#                                                         'href': None,
#                                                         'plain_text': 'ya',
#                                                         'text': {'content': 'ya',
#                                                                  'link': None},
#                                                         'type': 'text'},
#                                                        {'annotations': {'bold': False,
#                                                                         'code': True,
#                                                                         'color': 'green_background',
#                                                                         'italic': False,
#                                                                         'strikethrough': False,
#                                                                         'underline': False},
#                                                         'href': None,
#                                                         'plain_text': 'y',
#                                                         'text': {'content': 'y',
#                                                                  'link': None},
#                                                         'type': 'text'},
#                                                        {'annotations': {'bold': False,
#                                                                         'code': True,
#                                                                         'color': 'red_background',
#                                                                         'italic': False,
#                                                                         'strikethrough': False,
#                                                                         'underline': False},
#                                                         'href': None,
#                                                         'plain_text': 'a',
#                                                         'text': {'content': 'a',
#                                                                  'link': None},
#                                                         'type': 'text'},
#                                                        {'annotations': {'bold': False,
#                                                                         'code': False,
#                                                                         'color': 'green_background',
#                                                                         'italic': False,
#                                                                         'strikethrough': False,
#                                                                         'underline': False},
#                                                         'href': None,
#                                                         'plain_text': ' ',
#                                                         'text': {'content': ' ',
#                                                                  'link': None},
#                                                         'type': 'text'},
#                                                        {'annotations': {'bold': True,
#                                                                         'code': False,
#                                                                         'color': 'green_background',
#                                                                         'italic': False,
#                                                                         'strikethrough': False,
#                                                                         'underline': False},
#                                                         'href': None,
#                                                         'plain_text': 'ds',
#                                                         'text': {'content': 'ds',
#                                                                  'link': None},
#                                                         'type': 'text'},
#                                                        {'annotations': {'bold': False,
#                                                                         'code': False,
#                                                                         'color': 'default',
#                                                                         'italic': False,
#                                                                         'strikethrough': False,
#                                                                         'underline': False},
#                                                         'href': None,
#                                                         'plain_text': ' trata\n'
#                                                                       '\n'
#                                                                       '@teremterem\n'
#                                                                       '\n',
#                                                         'text': {'content': ' '
#                                                                             'trata\n'
#                                                                             '\n'
#                                                                             '@teremterem\n'
#                                                                             '\n',
#                                                                  'link': None},
#                                                         'type': 'text'},
#                                                        {'annotations': {'bold': False,
#                                                                         'code': True,
#                                                                         'color': 'default',
#                                                                         'italic': False,
#                                                                         'strikethrough': False,
#                                                                         'underline': False},
#                                                         'href': None,
#                                                         'plain_text': 'code',
#                                                         'text': {'content': 'code',
#                                                                  'link': None},
#                                                         'type': 'text'}],
#                                          'type': 'rich_text'},
#                              'Name': {'id': 'title',
#                                       'title': [{'annotations': {'bold': False,
#                                                                  'code': False,
#                                                                  'color': 'green_background',
#                                                                  'italic': False,
#                                                                  'strikethrough': False,
#                                                                  'underline': False},
#                                                  'href': None,
#                                                  'plain_text': 'yaya',
#                                                  'text': {'content': 'yaya',
#                                                           'link': None},
#                                                  'type': 'text'}],
#                                       'type': 'title'},
#                              'Tags': {'id': 'RAZd',
#                                       'multi_select': None,
#                                       'type': 'multi_select'}},
#               'url': 'https://www.notion.so/yaya-5cea696ecbec43c0bceae4ff7b98b25a'},
#              {'archived': False,
#               'cover': None,
#               'created_time': '2021-10-09T14:07:00.000Z',
#               'icon': None,
#               'id': '519e4b50-0a67-46f8-ab21-3f95db1d5cdd',
#               'last_edited_time': '2021-10-09T18:52:00.000Z',
#               'object': 'page',
#               'parent': {'database_id': '170ff8e0-2d71-4a9f-a4c4-ca3fd450f283',
#                          'type': 'database_id'},
#               'properties': {'Message': {'id': '%3DCG%3D',
#                                          'rich_text': [{'annotations': {'bold': False,
#                                                                         'code': False,
#                                                                         'color': 'default',
#                                                                         'italic': False,
#                                                                         'strikethrough': False,
#                                                                         'underline': False},
#                                                         'href': None,
#                                                         'plain_text': 'Hello, '
#                                                                       "I'm "
#                                                                       "Oleksandr's ",
#                                                         'text': {'content': 'Hello, '
#                                                                             "I'm "
#                                                                             "Oleksandr's ",
#                                                                  'link': None},
#                                                         'type': 'text'},
#                                                        {'annotations': {'bold': True,
#                                                                         'code': False,
#                                                                         'color': 'default',
#                                                                         'italic': False,
#                                                                         'strikethrough': False,
#                                                                         'underline': False},
#                                                         'href': None,
#                                                         'plain_text': 'SpokesPersonBot',
#                                                         'text': {'content': 'SpokesPersonBot',
#                                                                  'link': None},
#                                                         'type': 'text'},
#                                                        {'annotations': {'bold': False,
#                                                                         'code': False,
#                                                                         'color': 'default',
#                                                                         'italic': False,
#                                                                         'strikethrough': False,
#                                                                         'underline': False},
#                                                         'href': None,
#                                                         'plain_text': ' ;)',
#                                                         'text': {'content': ' '
#                                                                             ';)',
#                                                                  'link': None},
#                                                         'type': 'text'}],
#                                          'type': 'rich_text'},
#                              'Name': {'id': 'title',
#                                       'title': [{'annotations': {'bold': False,
#                                                                  'code': False,
#                                                                  'color': 'default',
#                                                                  'italic': False,
#                                                                  'strikethrough': False,
#                                                                  'underline': False},
#                                                  'href': None,
#                                                  'plain_text': '/start',
#                                                  'text': {'content': '/start',
#                                                           'link': None},
#                                                  'type': 'text'}],
#                                       'type': 'title'},
#                              'Tags': {'id': 'RAZd',
#                                       'multi_select': None,
#                                       'type': 'multi_select'}},
#               'url': 'https://www.notion.so/start-519e4b500a6746f8ab213f95db1d5cdd'}]}

# %%
def collect_plain_text(rich_text_list):
    text = ''.join([i['plain_text'] for i in rich_text_list])
    return text


entry_msg_dict = {}
for res in entrypoints_db_content['results']:
    key = collect_plain_text(res['properties']['Name']['title'])
    value = collect_plain_text(res['properties']['Message']['rich_text'])
    entry_msg_dict[key] = value

pprint(entry_msg_dict)
# Out:
# {'/starpt': 'BOLD bold\n'
#             'italic, <em>italic</em>\n'
#             'underline, <ins>underline</ins>\n'
#             'strikethrough, <strike>strikethrough</strike>, '
#             '<del>strikethrough</del>\n'
#             'bold italic bold italic bold strikethrough underline italic bold '
#             'bold\n'
#             '<a href="http://www.example.com/">inline URL</a>\n'
#             '[uuuser](tg://user?id=210723289)\n'
#             '\n'
#             '[user](https://www.google.com/)\n'
#             '\n'
#             '<code>inline fixed-width code</code>\n'
#             '<pre>pre-formatted fixed-width code block</pre>\n'
#             '<pre><code class="language-python">pre-formatted fixed-width code '
#             'block written in the Python programming language</code></pre>',
#  '/start': "Hello, I'm Oleksandr's SpokesPersonBot ;)",
#  'la': 'la la la la',
#  'ta': 'blah BLAH blah blah blah blah blah blah blah BLAH blah',
#  'test styles': 'rerere rererer boit\n'
#                 '\n'
#                 'bobobo ititit\n'
#                 'unders\n'
#                 'a url tratata\n'
#                 '\n'
#                 'All <, > and & symbols " \'',
#  'tototo': '',
#  'yaya': 'yaya ds trata\n\n@teremterem\n\ncode'}
