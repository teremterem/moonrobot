# %%
import os
from pprint import pprint

import requests
from dotenv import load_dotenv

load_dotenv()

MOONROBOT_NOTION_TOKEN = os.environ['MOONROBOT_NOTION_TOKEN']

# %%
with requests.post(
        'https://api.notion.com/v1/search',
        headers={
            'Authorization': f"Bearer {MOONROBOT_NOTION_TOKEN}",
            'Notion-Version': '2021-08-16',
        },
        json={},
) as resp:
    pprint(resp.json())
# Out:
# {'has_more': False,
#  'next_cursor': None,
#  'object': 'list',
#  'results': [{'archived': False,
#               'cover': None,
#               'created_time': '2021-10-09T12:51:00.000Z',
#               'icon': None,
#               'id': '0e18b425-0e6d-4d17-9111-dbec26065e6c',
#               'last_edited_time': '2021-10-09T14:19:00.000Z',
#               'object': 'page',
#               'parent': {'page_id': '2094ac20-ffdb-40b0-8491-f4b43b4bc6fb',
#                          'type': 'page_id'},
#               'properties': {'title': {'id': 'title',
#                                        'title': [{'annotations': {'bold': False,
#                                                                   'code': False,
#                                                                   'color': 'default',
#                                                                   'italic': False,
#                                                                   'strikethrough': False,
#                                                                   'underline': False},
#                                                   'href': None,
#                                                   'plain_text': 'Bot-12321',
#                                                   'text': {'content': 'Bot-12321',
#                                                            'link': None},
#                                                   'type': 'text'}],
#                                        'type': 'title'}},
#               'url': 'https://www.notion.so/Bot-12321-0e18b4250e6d4d179111dbec26065e6c'},
#              {'archived': False,
#               'cover': None,
#               'created_time': '2021-10-09T14:07:00.000Z',
#               'icon': None,
#               'id': '519e4b50-0a67-46f8-ab21-3f95db1d5cdd',
#               'last_edited_time': '2021-10-09T14:18:00.000Z',
#               'object': 'page',
#               'parent': {'database_id': '170ff8e0-2d71-4a9f-a4c4-ca3fd450f283',
#                          'type': 'database_id'},
#               'properties': {'Message': {'id': '%3DCG%3D',
#                                          'rich_text': [{'annotations': {'bold': False,
#                                                                         'code': False,
#                                                                         'color': 'default',
#                                                                         'italic': False,
#                                                                         'strikethrough': False,
#                                                                         'underline': False},
#                                                         'href': None,
#                                                         'plain_text': 'Hello, '
#                                                                       "I'm ",
#                                                         'text': {'content': 'Hello, '
#                                                                             "I'm ",
#                                                                  'link': None},
#                                                         'type': 'text'},
#                                                        {'annotations': {'bold': True,
#                                                                         'code': False,
#                                                                         'color': 'default',
#                                                                         'italic': False,
#                                                                         'strikethrough': False,
#                                                                         'underline': False},
#                                                         'href': None,
#                                                         'plain_text': "Oleksandr's",
#                                                         'text': {'content': "Oleksandr's",
#                                                                  'link': None},
#                                                         'type': 'text'},
#                                                        {'annotations': {'bold': False,
#                                                                         'code': False,
#                                                                         'color': 'default',
#                                                                         'italic': False,
#                                                                         'strikethrough': False,
#                                                                         'underline': False},
#                                                         'href': None,
#                                                         'plain_text': ' '
#                                                                       'SpokesPersonBot '
#                                                                       ';)',
#                                                         'text': {'content': ' '
#                                                                             'SpokesPersonBot '
#                                                                             ';)',
#                                                                  'link': None},
#                                                         'type': 'text'}],
#                                          'type': 'rich_text'},
#                              'Name': {'id': 'title',
#                                       'title': [{'annotations': {'bold': False,
#                                                                  'code': False,
#                                                                  'color': 'default',
#                                                                  'italic': False,
#                                                                  'strikethrough': False,
#                                                                  'underline': False},
#                                                  'href': None,
#                                                  'plain_text': '/start',
#                                                  'text': {'content': '/start',
#                                                           'link': None},
#                                                  'type': 'text'}],
#                                       'type': 'title'},
#                              'Tags': {'id': 'RAZd',
#                                       'multi_select': None,
#                                       'type': 'multi_select'}},
#               'url': 'https://www.notion.so/start-519e4b500a6746f8ab213f95db1d5cdd'},
#              {'cover': None,
#               'created_time': '2021-10-09T13:27:00.000Z',
#               'icon': None,
#               'id': '170ff8e0-2d71-4a9f-a4c4-ca3fd450f283',
#               'last_edited_time': '2021-10-09T14:09:00.000Z',
#               'object': 'database',
#               'parent': {'page_id': '0e18b425-0e6d-4d17-9111-dbec26065e6c',
#                          'type': 'page_id'},
#               'properties': {'Message': {'id': '%3DCG%3D',
#                                          'name': 'Message',
#                                          'rich_text': {},
#                                          'type': 'rich_text'},
#                              'Name': {'id': 'title',
#                                       'name': 'Name',
#                                       'title': {},
#                                       'type': 'title'},
#                              'Tags': {'id': 'RAZd',
#                                       'multi_select': {'options': []},
#                                       'name': 'Tags',
#                                       'type': 'multi_select'}},
#               'title': [{'annotations': {'bold': False,
#                                          'code': False,
#                                          'color': 'default',
#                                          'italic': False,
#                                          'strikethrough': False,
#                                          'underline': False},
#                          'href': None,
#                          'plain_text': 'Entrypoints',
#                          'text': {'content': 'Entrypoints', 'link': None},
#                          'type': 'text'}],
#               'url': 'https://www.notion.so/170ff8e02d714a9fa4c4ca3fd450f283'}]}
