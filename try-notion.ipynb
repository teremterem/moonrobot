# %%
from pprint import pprint

import requests
from dotenv import load_dotenv

load_dotenv()

import moonrobot

# %%
with requests.post(
        'https://api.notion.com/v1/search',
        headers={
            'Authorization': f"Bearer {moonrobot.MOONROBOT_NOTION_TOKEN}",
            'Notion-Version': '2021-08-16',
        },
        json={},
) as resp:
    pprint(resp.json())
# Out:
# {'has_more': False,
#  'next_cursor': None,
#  'object': 'list',
#  'results': [{'archived': False,
#               'cover': None,
#               'created_time': '2021-10-04T21:30:00.000Z',
#               'icon': None,
#               'id': '17694a67-520d-40bc-8034-888637f360c6',
#               'last_edited_time': '2021-10-04T21:36:00.000Z',
#               'object': 'page',
#               'parent': {'database_id': 'd958db09-fb40-4aa4-958a-b3fce9e7e305',
#                          'type': 'database_id'},
#               'properties': {'Message': {'id': 'PJFt',
#                                          'rich_text': [{'annotations': {'bold': False,
#                                                                         'code': False,
#                                                                         'color': 'default',
#                                                                         'italic': False,
#                                                                         'strikethrough': False,
#                                                                         'underline': False},
#                                                         'href': None,
#                                                         'plain_text': 'Hi from '
#                                                                       'Notion '
#                                                                       '=)',
#                                                         'text': {'content': 'Hi '
#                                                                             'from '
#                                                                             'Notion '
#                                                                             '=)',
#                                                                  'link': None},
#                                                         'type': 'text'}],
#                                          'type': 'rich_text'},
#                              'Name': {'id': 'title',
#                                       'title': [{'annotations': {'bold': False,
#                                                                  'code': False,
#                                                                  'color': 'default',
#                                                                  'italic': False,
#                                                                  'strikethrough': False,
#                                                                  'underline': False},
#                                                  'href': None,
#                                                  'plain_text': 'start3',
#                                                  'text': {'content': 'start3',
#                                                           'link': None},
#                                                  'type': 'text'}],
#                                       'type': 'title'},
#                              'Tags': {'id': 'Chrb',
#                                       'multi_select': None,
#                                       'type': 'multi_select'}},
#               'url': 'https://www.notion.so/start3-17694a67520d40bc8034888637f360c6'},
#              {'archived': False,
#               'cover': None,
#               'created_time': '2021-10-04T21:30:00.000Z',
#               'icon': None,
#               'id': 'e66a5152-1362-43f1-a8af-be332b9d0694',
#               'last_edited_time': '2021-10-04T21:31:00.000Z',
#               'object': 'page',
#               'parent': {'database_id': 'd958db09-fb40-4aa4-958a-b3fce9e7e305',
#                          'type': 'database_id'},
#               'properties': {'Message': {'id': 'PJFt',
#                                          'rich_text': [{'annotations': {'bold': False,
#                                                                         'code': False,
#                                                                         'color': 'default',
#                                                                         'italic': False,
#                                                                         'strikethrough': False,
#                                                                         'underline': False},
#                                                         'href': None,
#                                                         'plain_text': 'Hello ',
#                                                         'text': {'content': 'Hello ',
#                                                                  'link': None},
#                                                         'type': 'text'},
#                                                        {'annotations': {'bold': True,
#                                                                         'code': False,
#                                                                         'color': 'default',
#                                                                         'italic': False,
#                                                                         'strikethrough': False,
#                                                                         'underline': False},
#                                                         'href': None,
#                                                         'plain_text': 'from',
#                                                         'text': {'content': 'from',
#                                                                  'link': None},
#                                                         'type': 'text'},
#                                                        {'annotations': {'bold': False,
#                                                                         'code': False,
#                                                                         'color': 'default',
#                                                                         'italic': False,
#                                                                         'strikethrough': False,
#                                                                         'underline': False},
#                                                         'href': None,
#                                                         'plain_text': ' Notion '
#                                                                       '=)',
#                                                         'text': {'content': ' '
#                                                                             'Notion '
#                                                                             '=)',
#                                                                  'link': None},
#                                                         'type': 'text'}],
#                                          'type': 'rich_text'},
#                              'Name': {'id': 'title',
#                                       'title': [{'annotations': {'bold': False,
#                                                                  'code': False,
#                                                                  'color': 'default',
#                                                                  'italic': False,
#                                                                  'strikethrough': False,
#                                                                  'underline': False},
#                                                  'href': None,
#                                                  'plain_text': 'start1',
#                                                  'text': {'content': 'start1',
#                                                           'link': None},
#                                                  'type': 'text'}],
#                                       'type': 'title'},
#                              'Tags': {'id': 'Chrb',
#                                       'multi_select': None,
#                                       'type': 'multi_select'}},
#               'url': 'https://www.notion.so/start1-e66a5152136243f1a8afbe332b9d0694'},
#              {'cover': None,
#               'created_time': '2021-10-04T21:30:00.000Z',
#               'icon': None,
#               'id': 'd958db09-fb40-4aa4-958a-b3fce9e7e305',
#               'last_edited_time': '2021-10-04T21:31:00.000Z',
#               'object': 'database',
#               'parent': {'page_id': 'd4e2eb58-5bb8-45b8-aa9b-d3846dc5873f',
#                          'type': 'page_id'},
#               'properties': {'Message': {'id': 'PJFt',
#                                          'name': 'Message',
#                                          'rich_text': {},
#                                          'type': 'rich_text'},
#                              'Name': {'id': 'title',
#                                       'name': 'Name',
#                                       'title': {},
#                                       'type': 'title'},
#                              'Tags': {'id': 'Chrb',
#                                       'multi_select': {'options': []},
#                                       'name': 'Tags',
#                                       'type': 'multi_select'}},
#               'title': [{'annotations': {'bold': False,
#                                          'code': False,
#                                          'color': 'default',
#                                          'italic': False,
#                                          'strikethrough': False,
#                                          'underline': False},
#                          'href': None,
#                          'plain_text': 'Surreal Recruitee',
#                          'text': {'content': 'Surreal Recruitee', 'link': None},
#                          'type': 'text'}],
#               'url': 'https://www.notion.so/d958db09fb404aa4958ab3fce9e7e305'},
#              {'archived': False,
#               'cover': None,
#               'created_time': '2021-10-04T21:30:00.000Z',
#               'icon': None,
#               'id': '527f6c68-b052-4e1f-b31d-bc61593683b8',
#               'last_edited_time': '2021-10-04T21:31:00.000Z',
#               'object': 'page',
#               'parent': {'database_id': 'd958db09-fb40-4aa4-958a-b3fce9e7e305',
#                          'type': 'database_id'},
#               'properties': {'Message': {'id': 'PJFt',
#                                          'rich_text': [],
#                                          'type': 'rich_text'},
#                              'Name': {'id': 'title',
#                                       'title': [{'annotations': {'bold': False,
#                                                                  'code': False,
#                                                                  'color': 'default',
#                                                                  'italic': False,
#                                                                  'strikethrough': False,
#                                                                  'underline': False},
#                                                  'href': None,
#                                                  'plain_text': 'start2',
#                                                  'text': {'content': 'start2',
#                                                           'link': None},
#                                                  'type': 'text'}],
#                                       'type': 'title'},
#                              'Tags': {'id': 'Chrb',
#                                       'multi_select': None,
#                                       'type': 'multi_select'}},
#               'url': 'https://www.notion.so/start2-527f6c68b0524e1fb31dbc61593683b8'},
#              {'archived': False,
#               'cover': None,
#               'created_time': '2021-10-04T21:28:00.000Z',
#               'icon': None,
#               'id': 'd4e2eb58-5bb8-45b8-aa9b-d3846dc5873f',
#               'last_edited_time': '2021-10-04T21:30:00.000Z',
#               'object': 'page',
#               'parent': {'type': 'workspace', 'workspace': True},
#               'properties': {'title': {'id': 'title',
#                                        'title': [{'annotations': {'bold': False,
#                                                                   'code': False,
#                                                                   'color': 'default',
#                                                                   'italic': False,
#                                                                   'strikethrough': False,
#                                                                   'underline': False},
#                                                   'href': None,
#                                                   'plain_text': 'Checkpoints',
#                                                   'text': {'content': 'Checkpoints',
#                                                            'link': None},
#                                                   'type': 'text'}],
#                                        'type': 'title'}},
#               'url': 'https://www.notion.so/Checkpoints-d4e2eb585bb845b8aa9bd3846dc5873f'}]}
